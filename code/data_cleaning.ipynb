# %%
import pandas as pd
import datetime

# %%
unclean_crime  = pd.read_csv('../original_datasets/unclean_crime.csv')
unclean_crime
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> unclean_crime  = pd.read_csv('../original_datasets/unclean_crime.csv')
#       <a href='vscode-notebook-cell:/Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> unclean_crime
#
# ...

# %%
unclean_crime.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
print(unclean_crime['ID'].nunique())
print(len(unclean_crime['ID']))
# Out:
# 7914425
# 7914425

# %%
print(unclean_crime['Case Number'].nunique())
print(len(unclean_crime['Case Number']))
# Out:
# 7913878
# 7914425

# %%
unclean_crime[unclean_crime['Case Number'].duplicated() == True]
# Out:
#             ID Case Number                    Date                    Block  \
# 110020   27774    JG446325  10/01/2023 03:43:00 PM       000XX S WHIPPLE ST
# 124172   27782    JG453003  10/06/2023 02:40:00 AM          018XX W 54TH ST
# 126814   27788    JG456963  10/09/2023 03:03:00 PM      062XX S ASHLAND AVE
# 2118812  25213    JD272406  06/22/2020 01:01:00 PM          086XX S WOOD ST
# 2121543  26147    JE175526  07/26/2021 12:57:00 PM     038XX S MICHIGAN AVE
# ...        ...         ...                     ...                      ...
# 2249887   5098    HR411763  07/05/2009 03:00:00 AM          012XX E 63RD ST
# 2249939  22240    HY551250  12/27/2015 06:05:00 AM    059XX S WENTWORTH AVE
# 2250145  21718    HY106072  01/06/2015 05:53:00 PM          022XX E 79TH ST
# 2250475   2811    HK509310  07/22/2004 11:35:00 AM  008XX N SPRINGFIELD AVE
# 2250614  19261    HS148489  02/02/2010 06:28:00 PM        085XX S MORGAN ST
#
# ...

# %%
unclean_crime[unclean_crime.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %%
unclean_crime.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
unclean_crime = unclean_crime[['Case Number', 'Date', 'Primary Type', 'Latitude', 'Longitude']]
unclean_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 0          JA371270  03/18/2015 12:00:00 PM   DECEPTIVE PRACTICE        NaN
# 1          JC213749  12/20/2018 03:00:00 PM   DECEPTIVE PRACTICE        NaN
# 2          JC212333  05/01/2016 12:25:00 AM   DECEPTIVE PRACTICE        NaN
# 3          JC211511  12/20/2018 04:00:00 PM        OTHER OFFENSE        NaN
# 4          JC212935  06/01/2014 12:01:00 AM   DECEPTIVE PRACTICE        NaN
# ...             ...                     ...                  ...        ...
# 7914420    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7914421    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7914422    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7914423    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7914424    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 0              NaN
# ...

# %%
unclean_crime = unclean_crime[unclean_crime.Latitude.isnull() == False]
unclean_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 11         JD226426  05/07/2020 10:24:00 AM                THEFT  41.830482
# 12         JD209965  04/16/2020 05:00:00 AM              BATTERY  41.836310
# 13         JD282112  07/01/2020 10:16:00 AM              ASSAULT  41.747610
# 14         JD381597  09/27/2020 11:29:00 PM              BATTERY  41.774878
# 15         HL474854  07/10/2005 03:00:00 PM              BATTERY  41.781003
# ...             ...                     ...                  ...        ...
# 7914420    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7914421    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7914422    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7914423    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7914424    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 11      -87.621752
# ...

# %%
unclean_crime.reset_index(drop=True, inplace=True)

# %%
unclean_crime
# Out:
#         Case Number                    Date         Primary Type   Latitude  \
# 0          JD226426  05/07/2020 10:24:00 AM                THEFT  41.830482
# 1          JD209965  04/16/2020 05:00:00 AM              BATTERY  41.836310
# 2          JD282112  07/01/2020 10:16:00 AM              ASSAULT  41.747610
# 3          JD381597  09/27/2020 11:29:00 PM              BATTERY  41.774878
# 4          HL474854  07/10/2005 03:00:00 PM              BATTERY  41.781003
# ...             ...                     ...                  ...        ...
# 7824312    JD327752  08/10/2020 08:30:00 PM             BURGLARY  41.772671
# 7824313    JD269218  06/18/2020 09:00:00 PM                THEFT  41.724546
# 7824314    JD311791  07/27/2020 03:02:00 PM              BATTERY  41.870921
# 7824315    JD340297  08/14/2020 03:00:00 PM  MOTOR VEHICLE THEFT  41.995927
# 7824316    JD177406  03/06/2020 02:00:00 PM   DECEPTIVE PRACTICE  41.942112
#
#          Longitude
# 0       -87.621752
# ...

# %%
unclean_crime = unclean_crime.sort_values(by='Date').reset_index(drop=True)

# %%
unclean_crime
# Out:
#         Case Number                    Date       Primary Type   Latitude  \
# 0           G001009  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.848786
# 1           G001554  01/01/2001 01:00:00 AM            BATTERY  41.765396
# 2           G001792  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.854014
# 3           G000876  01/01/2001 01:00:00 AM              THEFT  41.798298
# 4           G010990  01/01/2001 01:00:00 AM  WEAPONS VIOLATION  41.866694
# ...             ...                     ...                ...        ...
# 7824312    JF528687  12/31/2022 12:45:00 PM    CRIMINAL DAMAGE  41.874153
# 7824313    JF528703  12/31/2022 12:50:00 PM            ASSAULT  41.766546
# 7824314    JF528801  12/31/2022 12:50:00 PM            ASSAULT  41.855911
# 7824315    JF528218  12/31/2022 12:52:00 AM            BATTERY  41.868829
# 7824316    JF528704  12/31/2022 12:52:00 PM            ASSAULT  41.930693
#
#          Longitude
# 0       -87.704087
# 1       -87.626698
# ...

# %%
unclean_crime = unclean_crime.rename(columns={'Case Number' : 'id', 'Date': 'date', 'Primary Type' : 'type', 'Latitude' : 'lat', 'Longitude' : 'long'})
unclean_crime
# Out:
#                id                    date               type        lat  \
# 0         G001009  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.848786
# 1         G001554  01/01/2001 01:00:00 AM            BATTERY  41.765396
# 2         G001792  01/01/2001 01:00:00 AM    CRIMINAL DAMAGE  41.854014
# 3         G000876  01/01/2001 01:00:00 AM              THEFT  41.798298
# 4         G010990  01/01/2001 01:00:00 AM  WEAPONS VIOLATION  41.866694
# ...           ...                     ...                ...        ...
# 7824312  JF528687  12/31/2022 12:45:00 PM    CRIMINAL DAMAGE  41.874153
# 7824313  JF528703  12/31/2022 12:50:00 PM            ASSAULT  41.766546
# 7824314  JF528801  12/31/2022 12:50:00 PM            ASSAULT  41.855911
# 7824315  JF528218  12/31/2022 12:52:00 AM            BATTERY  41.868829
# 7824316  JF528704  12/31/2022 12:52:00 PM            ASSAULT  41.930693
#
#               long
# 0       -87.704087
# 1       -87.626698
# 2       -87.681909
# 3       -87.692856
# ...

# %%
unclean_crime = unclean_crime.sort_values(by='date').reset_index(drop=True)
unclean_crime
# Out:
#                id                 date                        type        lat  \
# 0        HJ215839  01/01/2001 00:00:00                       THEFT  41.780623
# 1         G007383  01/01/2001 00:00:00               OTHER OFFENSE  41.847059
# 2         G001433  01/01/2001 00:00:00             CRIMINAL DAMAGE  42.008635
# 3        HM417252  01/01/2001 00:00:00                       THEFT  41.834523
# 4        HP199889  01/01/2001 00:00:00  OFFENSE INVOLVING CHILDREN  41.878582
# ...           ...                  ...                         ...        ...
# 7824312  JG100071  12/31/2022 23:45:00                     BATTERY  41.884437
# 7824313  JG100005  12/31/2022 23:47:00           WEAPONS VIOLATION  41.727812
# 7824314  JG100087  12/31/2022 23:47:00                     ASSAULT  41.727812
# 7824315  JG100085  12/31/2022 23:50:00                     BATTERY  41.882257
# 7824316  JG100016  12/31/2022 23:50:00         MOTOR VEHICLE THEFT  42.009108
#
#               long
# ...

# %%
unclean_crime.to_csv('../clean_datasets/clean_crime.csv')

# %%
unclean_alleylights = pd.read_csv('../original_datasets/unclean_alleylights.csv')

# %%
unclean_alleylights.head()
# Out:
#   Creation Date     Status Completion Date Service Request Number  \
# 0    09/18/2012  Completed      09/18/2012            12-01630621
# 1    06/03/2013  Completed      06/03/2013            13-00682254
# 2    06/18/2013  Completed      06/18/2013            13-00775171
# 3    06/20/2013  Completed      06/20/2013            13-00792289
# 4    08/09/2017  Completed      10/11/2017            17-05325459
#
#   Type of Service Request        Street Address  ZIP Code  X Coordinate  \
# 0         Alley Light Out                   NaN       NaN           NaN
# 1         Alley Light Out              1 W LAKE       NaN           NaN
# 2         Alley Light Out    4300 S ASHLAND AVE   60646.0           NaN
# 3         Alley Light Out            520 W 66TH       NaN           NaN
# 4         Alley Light Out  1819 W EVERGREEN AVE   60622.0  1.163763e+06
#
#    Y Coordinate  Ward  Police District  Community Area   Latitude  Longitude  \
# ...

# %%
unclean_alleylights = unclean_alleylights[['Creation Date', 'Service Request Number', 'Type of Service Request', 'Latitude', 'Longitude']]
unclean_alleylights
# Out:
#        Creation Date Service Request Number Type of Service Request  \
# 0         09/18/2012            12-01630621         Alley Light Out
# 1         06/03/2013            13-00682254         Alley Light Out
# 2         06/18/2013            13-00775171         Alley Light Out
# 3         06/20/2013            13-00792289         Alley Light Out
# 4         08/09/2017            17-05325459         Alley Light Out
# ...              ...                    ...                     ...
# 121818    11/17/2016            16-07876733         Alley Light Out
# 121819    09/28/2016            16-06828101         Alley Light Out
# 121820    05/24/2016            16-03597363         Alley Light Out
# 121821    11/22/2016            16-07951223         Alley Light Out
# 121822    01/23/2017            17-00418045         Alley Light Out
#
#          Latitude  Longitude
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# ...

# %%
unclean_alleylights.rename(columns={'Creation Date' : 'date', 'Service Request Number' : 'id', 'Type of Service Request' : 'type', 'Latitude': 'lat', 'Longitude' : 'long'}, inplace=True)
unclean_alleylights
# Out:
#               date           id             type        lat       long
# 0       09/18/2012  12-01630621  Alley Light Out        NaN        NaN
# 1       06/03/2013  13-00682254  Alley Light Out        NaN        NaN
# 2       06/18/2013  13-00775171  Alley Light Out        NaN        NaN
# 3       06/20/2013  13-00792289  Alley Light Out        NaN        NaN
# 4       08/09/2017  17-05325459  Alley Light Out  41.907802 -87.673858
# ...            ...          ...              ...        ...        ...
# 121818  11/17/2016  16-07876733  Alley Light Out        NaN        NaN
# 121819  09/28/2016  16-06828101  Alley Light Out        NaN        NaN
# 121820  05/24/2016  16-03597363  Alley Light Out        NaN        NaN
# 121821  11/22/2016  16-07951223  Alley Light Out        NaN        NaN
# 121822  01/23/2017  17-00418045  Alley Light Out        NaN        NaN
#
# [121823 rows x 5 columns]

# %%
sum(unclean_alleylights.lat.isnull()) / len(unclean_alleylights)
# Out:
# 0.0006977335971039951

# %%
unclean_alleylights.dropna(subset=['lat', 'long'], inplace=True)
unclean_alleylights
# Out:
#               date           id             type        lat       long
# 4       08/09/2017  17-05325459  Alley Light Out  41.907802 -87.673858
# 5       08/05/2017  17-05207618  Alley Light Out  41.763091 -87.629040
# 6       08/30/2017  17-05786295  Alley Light Out  41.688918 -87.701947
# 7       03/28/2017  17-01732622  Alley Light Out  41.868173 -87.771769
# 8       08/26/2014  14-01418678  Alley Light Out  41.662853 -87.557743
# ...            ...          ...              ...        ...        ...
# 121809  01/03/2012  12-00007804  Alley Light Out  41.782132 -87.786317
# 121810  04/13/2011  11-00809220  Alley Light Out  41.967814 -87.680776
# 121811  12/03/2013  13-01801777  Alley Light Out  41.949465 -87.772257
# 121812  11/09/2015  15-06045450  Alley Light Out  41.713483 -87.623253
# 121813  05/17/2011  11-01833147  Alley Light Out  41.784704 -87.659489
#
# [121738 rows x 5 columns]

# %%
unclean_alleylights.sort_values(by='date', inplace=True)
unclean_alleylights.reset_index(drop=True, inplace=True)
unclean_alleylights
# Out:
#               date           id             type        lat       long
# 0       01/01/2011  11-00003272  Alley Light Out  41.906793 -87.731329
# 1       01/01/2011  11-00002501  Alley Light Out  42.001225 -87.698047
# 2       01/01/2011  11-00002403  Alley Light Out  41.809197 -87.728527
# 3       01/01/2011  11-00003393  Alley Light Out  41.794302 -87.645160
# 4       01/01/2011  11-00003042  Alley Light Out  41.765039 -87.719968
# ...            ...          ...              ...        ...        ...
# 121733  12/31/2016  16-08556938  Alley Light Out  41.797131 -87.753186
# 121734  12/31/2017  17-08702805  Alley Light Out  41.783693 -87.610878
# 121735  12/31/2017  17-08704681  Alley Light Out  41.976628 -87.751879
# 121736  12/31/2017  17-08702313  Alley Light Out  41.939668 -87.640912
# 121737  12/31/2017  17-08704538  Alley Light Out  41.774704 -87.796851
#
# [121738 rows x 5 columns]

# %%
print(unclean_alleylights.id.nunique())
print(len(unclean_alleylights))
# Out:
# 121688
# 121738

# %%
unclean_alleylights = unclean_alleylights[unclean_alleylights.duplicated() == False]

# %%
unclean_alleylights.type.nunique()
# Out:
# 1

# %%
unclean_alleylights['type'] = 'alley'
unclean_alleylights
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/3456936074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_alleylights['type'] = 'alley'
#               date           id   type        lat       long
# 0       01/01/2011  11-00003272  alley  41.906793 -87.731329
# 1       01/01/2011  11-00002501  alley  42.001225 -87.698047
# 2       01/01/2011  11-00002403  alley  41.809197 -87.728527
# 3       01/01/2011  11-00003393  alley  41.794302 -87.645160
# 4       01/01/2011  11-00003042  alley  41.765039 -87.719968
# ...            ...          ...    ...        ...        ...
# 121733  12/31/2016  16-08556938  alley  41.797131 -87.753186
# 121734  12/31/2017  17-08702805  alley  41.783693 -87.610878
# ...

# %%
def clean_data(df, type):
    df = df[['Creation Date', 'Service Request Number', 'Type of Service Request', 'Latitude', 'Longitude']]
    df.rename(columns={'Creation Date' : 'date', 'Service Request Number' : 'id', 'Type of Service Request' : 'type', 'Latitude': 'lat', 'Longitude' : 'long'}, inplace=True)
    perc_null = sum(df.lat.isnull()) / len(df)
    if perc_null > 0.005:
        print(f'perc_null of {perc_null} is too large to clean')
    else:
        df.dropna(subset=['lat', 'long'], inplace=True)
        print(f'successfully removed {sum(df.lat.isnull())} nulls or {perc_null}%')
    df.sort_values(by='date', inplace=True)
    df.reset_index(drop=True, inplace=True)
    df['type'] = type
    return df

# %%
unclean_streetlights_allout = pd.read_csv('../original_datasets/unclean_streetlights_allout.csv')
unclean_streetlights_allout
# Out:
#        Creation Date     Status Completion Date Service Request Number  \
# 0         10/11/2017  Completed      10/11/2017            17-06816558
# 1         10/09/2017  Completed      10/11/2017            17-06772762
# 2         10/09/2017  Completed      10/11/2017            17-06756084
# 3         10/10/2017  Completed      10/11/2017            17-06786335
# 4         10/11/2017  Completed      10/11/2017            17-06824676
# ...              ...        ...             ...                    ...
# 147008    01/12/2013  Completed      01/15/2013            13-00048005
# 147009    08/10/2011  Completed      08/15/2011            11-03564441
# 147010    10/22/2013  Completed      10/22/2013            13-01584230
# 147011    03/28/2012  Completed      03/29/2012            12-00682526
# 147012    01/01/2013  Completed      01/03/2013            13-00000198
#
#         Type of Service Request           Street Address  ZIP Code  \
# ...

# %%
unclean_streetlights_allout  = clean_data(unclean_streetlights_allout, 'sl_all')
unclean_streetlights_allout
# Out:
# successfully removed 0 nulls or 0.0007210246712875732%
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/3849291121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Creation Date' : 'date', 'Service Request Number' : 'id', 'Type of Service Request' : 'type', 'Latitude': 'lat', 'Longitude' : 'long'}, inplace=True)
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/3849291121.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['lat', 'long'], inplace=True)
# ...

# %%
unclean_streetlights_oneout = pd.read_csv('../original_datasets/unclean_streetlights_oneout.csv')
unclean_streetlights_oneout
# Out:
#        Creation Date     Status Completion Date Service Request Number  \
# 0         02/19/2013  Completed      02/19/2013            13-00189592
# 1         02/22/2013  Completed      02/22/2013            13-00204821
# 2         03/04/2013  Completed      03/15/2013            13-00242776
# 3         03/20/2012  Completed      04/03/2012            12-00641038
# 4         03/25/2013  Completed      03/25/2013            13-00330005
# ...              ...        ...             ...                    ...
# 134867    11/07/2018  Completed      11/08/2018            18-03110724
# 134868    08/08/2018  Completed      11/05/2018            18-02331140
# 134869    11/27/2018       Open             NaN            18-03232518
# 134870    11/03/2018  Completed      11/05/2018            18-03079134
# 134871    10/11/2018  Completed      10/16/2018            18-02899892
#
#        Type of Service Request      Street Address  ZIP Code  X Coordinate  \
# ...

# %%
unclean_streetlights_oneout = clean_data(unclean_streetlights_oneout, 'sl_one')
unclean_streetlights_oneout
# Out:
# successfully removed 0 nulls or 0.0024838365264843705%
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/3849291121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Creation Date' : 'date', 'Service Request Number' : 'id', 'Type of Service Request' : 'type', 'Latitude': 'lat', 'Longitude' : 'long'}, inplace=True)
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/3849291121.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['lat', 'long'], inplace=True)
# ...

# %%
unclean_vacant_buildings = pd.read_csv('../original_datasets/unclean_vacant_buildings.csv')
unclean_vacant_buildings
# Out:
#             SERVICE REQUEST TYPE SERVICE REQUEST NUMBER  \
# 0      Vacant/Abandoned Building            17-06828959
# 1      Vacant/Abandoned Building            17-06827096
# 2      Vacant/Abandoned Building            17-06818719
# 3      Vacant/Abandoned Building            17-06824436
# 4      Vacant/Abandoned Building            17-06826684
# ...                          ...                    ...
# 65114  Vacant/Abandoned Building            18-03384005
# 65115  Vacant/Abandoned Building            18-03380438
# 65116  Vacant/Abandoned Building            18-03379703
# 65117  Vacant/Abandoned Building            18-03382499
# 65118  Vacant/Abandoned Building            16-02925607
#
#       DATE SERVICE REQUEST WAS RECEIVED  \
# 0                            10/11/2017
# 1                            10/11/2017
# 2                            10/11/2017
# 3                            10/11/2017
# 4                            10/11/2017
# ...                                 ...
# ...

# %%
unclean_vacant_buildings = unclean_vacant_buildings[['DATE SERVICE REQUEST WAS RECEIVED', 'SERVICE REQUEST NUMBER', 'SERVICE REQUEST TYPE', 'LATITUDE', 'LONGITUDE']]
unclean_vacant_buildings.rename(columns={'DATE SERVICE REQUEST WAS RECEIVED' : 'date', 'SERVICE REQUEST NUMBER' : 'id', 'SERVICE REQUEST TYPE' : 'type', 'LATITUDE': 'lat', 'LONGITUDE' : 'long'}, inplace=True)
perc_null = sum(unclean_vacant_buildings.lat.isnull()) / len(unclean_vacant_buildings)
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/1066417329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_vacant_buildings.rename(columns={'DATE SERVICE REQUEST WAS RECEIVED' : 'date', 'SERVICE REQUEST NUMBER' : 'id', 'SERVICE REQUEST TYPE' : 'type', 'LATITUDE': 'lat', 'LONGITUDE' : 'long'}, inplace=True)

# %%
print(perc_null)
unclean_vacant_buildings
# Out:
# 0.0007063990540395277
#              date           id                       type        lat  \
# 0      10/11/2017  17-06828959  Vacant/Abandoned Building  41.753463
# 1      10/11/2017  17-06827096  Vacant/Abandoned Building  41.774412
# 2      10/11/2017  17-06818719  Vacant/Abandoned Building  41.702514
# 3      10/11/2017  17-06824436  Vacant/Abandoned Building  41.789879
# 4      10/11/2017  17-06826684  Vacant/Abandoned Building  41.721604
# ...           ...          ...                        ...        ...
# 65114  12/17/2018  18-03384005  Vacant/Abandoned Building  41.741764
# 65115  12/17/2018  18-03380438  Vacant/Abandoned Building  41.744965
# 65116  12/17/2018  18-03379703  Vacant/Abandoned Building  41.752659
# 65117  12/17/2018  18-03382499  Vacant/Abandoned Building  41.894108
# 65118  04/29/2016  16-02925607  Vacant/Abandoned Building        NaN
#
#             long
# 0     -87.657041
# 1     -87.611883
# 2     -87.630974
# 3     -87.643825
# 4     -87.632602
# ...

# %%
unclean_vacant_buildings.dropna(subset=['lat', 'long'], inplace=True)
unclean_vacant_buildings.sort_values(by='date', inplace=True)
unclean_vacant_buildings.reset_index(drop=True, inplace=True)
unclean_vacant_buildings['type'] = 'vacant_building'
unclean_vacant_buildings
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/1805212223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_vacant_buildings.dropna(subset=['lat', 'long'], inplace=True)
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/1805212223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_vacant_buildings.sort_values(by='date', inplace=True)
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_3322/1805212223.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfs = [unclean_alleylights, unclean_streetlights_allout, unclean_streetlights_oneout, unclean_vacant_buildings]

# %%
unclean_311 = pd.concat(dfs)
unclean_311
# Out:
#               date           id             type        lat       long
# 0       01/01/2011  11-00003272            alley  41.906793 -87.731329
# 1       01/01/2011  11-00003398           sl_all  41.681558 -87.632377
# 2       01/01/2011  11-00003463           sl_all  41.793832 -87.652439
# 3       01/01/2011  11-00003050           sl_all  41.735984 -87.649848
# 4       01/01/2011  11-00003307           sl_all  41.783295 -87.775365
# ...            ...          ...              ...        ...        ...
# 468200  12/31/2017  17-08693699           sl_all  41.936554 -87.641858
# 468201  12/31/2017  17-08704538            alley  41.774704 -87.796851
# 468202  12/31/2017  17-08702313            alley  41.939668 -87.640912
# 468203  12/31/2017  17-08702201           sl_one  41.740289 -87.550252
# 468204  12/31/2017  17-08691267  vacant_building  41.793890 -87.676789
#
# [468205 rows x 5 columns]

# %%
unclean_311['date'] = [datetime.datetime.strptime(unclean_311.date.loc[i], '%m/%d/%Y') for i in range(len(unclean_311))]
unclean_311
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell:/Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> unclean_311['date'] = [datetime.datetime.strptime(unclean_311.date.loc[i], '%m/%d/%Y') for i in range(len(unclean_311))]
#       <a href='vscode-notebook-cell:/Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> unclean_311.sort_values(by='date', inplace=True)
#       <a href='vscode-notebook-cell:/Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb#X63sZmlsZQ%3D%3D?line=2'>3</a> unclean_311.reset_index(drop=True, inplace=True)
#
# /Users/evanmeyer/Desktop/Chicago_ML/code/data_cleaning.ipynb Cell 39 line 1
# ...

# %%
unclean_311.sort_values(by='date', inplace=True)
unclean_311.reset_index(drop=True, inplace=True)
clean_311 = unclean_311.tail(-4)
clean_311
# Out:
#              date           id             type        lat       long
# 4      2008-04-03  08-00577896  vacant_building  41.768198 -87.651771
# 5      2008-04-05  08-00588295  vacant_building  41.745482 -87.606287
# 6      2008-07-30  08-01476976  vacant_building  41.764674 -87.635884
# 7      2008-08-07  08-01559367  vacant_building  41.759564 -87.656096
# 8      2008-08-12  08-01602664  vacant_building  41.896242 -87.721220
# ...           ...          ...              ...        ...        ...
# 468200 2018-12-18  18-03387910           sl_all  41.853486 -87.717491
# 468201 2018-12-18  18-03388629            alley  41.721280 -87.657702
# 468202 2018-12-18  18-03388534           sl_all  41.690735 -87.626170
# 468203 2018-12-18  18-03388097           sl_all  41.737574 -87.659463
# 468204 2018-12-19  18-03389670           sl_one  41.851291 -87.674233
#
# [468201 rows x 5 columns]

# %%
clean_311.to_csv('../clean_datasets/clean_311.csv')

# %%
unclean_divvy_trips = pd.read_csv('../original_datasets/unclean_divvy_trips.csv')
unclean_divvy_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  BIKE ID  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM      979
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM     1932
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM     1693
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM     3370
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM     2563
# ...            ...                     ...                     ...      ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM     6352
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM     2485
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM     4305
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM     2373
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM      832
#
# ...

# %%
unclean_divvy_trips = unclean_divvy_trips[['TRIP ID', 'START TIME', 'STOP TIME', 'FROM STATION ID', 'FROM STATION NAME', 'TO STATION ID', 'TO STATION NAME']]
unclean_divvy_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM
# ...            ...                     ...                     ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM
#
#           FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0                     117    Wilton Ave & Belmont Ave            229
# ...

# %%
divvy_stations_a = unclean_divvy_trips[['FROM STATION ID', 'FROM STATION NAME']]
divvy_stations_b = unclean_divvy_trips[['TO STATION ID', 'TO STATION NAME']]
divvy_stations_a
# Out:
#           FROM STATION ID           FROM STATION NAME
# 0                     117    Wilton Ave & Belmont Ave
# 1                     301      Clark St & Schiller St
# 2                     465      Marine Dr & Ainslie St
# 3                     333  Ashland Ave & Blackhawk St
# 4                      48  Larrabee St & Kingsbury St
# ...                   ...                         ...
# 21242735               60       Dayton St & North Ave
# 21242736              110       Dearborn St & Erie St
# 21242737               69      Damen Ave & Pierce Ave
# 21242738              211      St. Clair St & Erie St
# 21242739              296      Broadway & Belmont Ave
#
# [21242740 rows x 2 columns]

# %%
divvy_stations_b
# Out:
#           TO STATION ID                              TO STATION NAME
# 0                   229                    Southport Ave & Roscoe St
# 1                   138                   Clybourn Ave & Division St
# 2                   251                   Clarendon Ave & Leland Ave
# 3                   198           Green St (Halsted St) & Madison St
# 4                   111                       Sedgwick St & Huron St
# ...                 ...                                          ...
# 21242735            332  Burling St (Halsted) & Diversey Pkwy (Temp)
# 21242736             38                           Clark St & Lake St
# 21242737            347                       Ashland Ave & Grace St
# 21242738            289                        Wells St & Concord Ln
# 21242739            332  Burling St (Halsted) & Diversey Pkwy (Temp)
#
# [21242740 rows x 2 columns]

# %%
clean_bike_stations = pd.read_csv('../clean_datasets/clean_bike_stations.csv')
clean_bike_stations
# Out:
#                                  station_name  total_docks  docks_in_service  \
# 0                      Troy St & Jackson Blvd            9                 9
# 1         Central Park Ave & Bloomingdale Ave           11                11
# 2         Public Rack - Cornell Ave & 87th Pl            1                 1
# 3                        Racine Ave & 35th St           15                15
# 4     Public Rack - Francisco Ave & Touhy Ave            2                 2
# ...                                       ...          ...               ...
# 1411             Sheffield Ave & Kingsbury St           15                15
# 1412                  Ogden Ave & Chicago Ave           19                19
# 1413                  Baltimore Ave & 87th St           15                15
# 1414             Ewing Ave & Burnham Greenway           11                11
# 1415                  Green St & Randolph St*           12                12
#
#        latitude  longitude
# ...

# %%
clean_bike_stations = clean_bike_stations[['station_name', 'latitude', 'longitude']]
clean_bike_stations.rename(columns={'station_name' : 'station', 'latitude' : 'lat', 'longitude' : 'long'}, inplace=True)
clean_bike_stations
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_4574/2968306599.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_bike_stations.rename(columns={'station_name' : 'station', 'latitude' : 'lat', 'longitude' : 'long'}, inplace=True)
#                                       station        lat       long
# 0                      Troy St & Jackson Blvd  41.877505 -87.704850
# 1         Central Park Ave & Bloomingdale Ave  41.914166 -87.716755
# 2         Public Rack - Cornell Ave & 87th Pl  41.736881 -87.583146
# 3                        Racine Ave & 35th St  41.830689 -87.656211
# 4     Public Rack - Francisco Ave & Touhy Ave  42.011865 -87.701317
# ...                                       ...        ...        ...
# ...

# %%
divvy_stations_a.rename(columns={'FROM STATION ID' : 'id', 'FROM STATION NAME' : 'station'}, inplace=True)
divvy_stations_a
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_4574/1916554095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   divvy_stations_a.rename(columns={'FROM STATION ID' : 'id', 'FROM STATION NAME' : 'station'}, inplace=True)
#            id                     station
# 0         117    Wilton Ave & Belmont Ave
# 1         301      Clark St & Schiller St
# 2         465      Marine Dr & Ainslie St
# 3         333  Ashland Ave & Blackhawk St
# 4          48  Larrabee St & Kingsbury St
# ...       ...                         ...
# 21242735   60       Dayton St & North Ave
# 21242736  110       Dearborn St & Erie St
# 21242737   69      Damen Ave & Pierce Ave
# 21242738  211      St. Clair St & Erie St
# 21242739  296      Broadway & Belmont Ave
#
# [21242740 rows x 2 columns]

# %%
clean_bike_stations = clean_bike_stations.merge(divvy_stations_a, on='station', how='inner')

# %%
clean_bike_stations.drop_duplicates(inplace=True)

# %%
clean_bike_stations = clean_bike_stations[clean_bike_stations.station.duplicated() == False]
clean_bike_stations.reset_index(drop=True, inplace=True)
clean_bike_stations
# Out:
#                                  station        lat       long   id
# 0    Central Park Ave & Bloomingdale Ave  41.914166 -87.716755  641
# 1                   Racine Ave & 35th St  41.830689 -87.656211  367
# 2                 Carpenter St & 63rd St  41.779870 -87.650919  648
# 3            Cottage Grove Ave & 63rd St  41.780531 -87.605970  427
# 4                Bernard St & Elston Ave  41.949923 -87.713949  640
# ..                                   ...        ...        ...  ...
# 570                       Shedd Aquarium  41.867226 -87.615355    3
# 571                Wells St & Hubbard St  41.889906 -87.634266  212
# 572             Marshfield Ave & 59th St  41.786833 -87.666215  560
# 573         Sheffield Ave & Kingsbury St  41.910522 -87.653106   20
# 574              Ogden Ave & Chicago Ave  41.896362 -87.654061   54
#
# [575 rows x 4 columns]

# %%
clean_bike_stations.to_csv('../clean_datasets/clean_bike_stations.csv')

# %%
unclean_divvy_trips
# Out:
#            TRIP ID              START TIME               STOP TIME  \
# 0          8546790  12/31/2015 05:35:00 PM  12/31/2015 05:44:00 PM
# 1          8546793  12/31/2015 05:37:00 PM  12/31/2015 05:41:00 PM
# 2          8546795  12/31/2015 05:37:00 PM  12/31/2015 05:40:00 PM
# 3          8546797  12/31/2015 05:38:00 PM  12/31/2015 05:55:00 PM
# 4          8546798  12/31/2015 05:38:00 PM  12/31/2015 05:41:00 PM
# ...            ...                     ...                     ...
# 21242735  25220103  09/30/2019 06:24:15 PM  09/30/2019 06:35:26 PM
# 21242736  25221957  09/30/2019 07:46:32 PM  09/30/2019 07:52:07 PM
# 21242737  25223072  09/30/2019 09:35:55 PM  09/30/2019 09:56:41 PM
# 21242738  25219153  09/30/2019 05:58:35 PM  09/30/2019 06:10:05 PM
# 21242739  25221024  09/30/2019 06:57:23 PM  09/30/2019 07:03:56 PM
#
#           FROM STATION ID           FROM STATION NAME  TO STATION ID  \
# 0                     117    Wilton Ave & Belmont Ave            229
# ...

# %%
unclean_divvy_trips_a = unclean_divvy_trips[['TRIP ID', 'START TIME', 'FROM STATION ID', 'FROM STATION NAME']]
unclean_divvy_trips_b = unclean_divvy_trips[['TRIP ID', 'START TIME', 'TO STATION ID', 'TO STATION NAME']]

# %%
unclean_divvy_trips_a.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'FROM STATION ID' : 'station_id', 'FROM STATION NAME' : 'station_name'}, inplace=True)
unclean_divvy_trips_b.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'TO STATION ID' : 'station_id', 'TO STATION NAME' : 'station_name'}, inplace=True)
# Out:
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_4574/1387481744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_divvy_trips_a.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'FROM STATION ID' : 'station_id', 'FROM STATION NAME' : 'station_name'}, inplace=True)
# /var/folders/5d/fdmfhfr55d5f2r62ltcl50vh0000gn/T/ipykernel_4574/1387481744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unclean_divvy_trips_b.rename(columns={'TRIP ID' : 'id', 'START TIME' : 'date', 'TO STATION ID' : 'station_id', 'TO STATION NAME' : 'station_name'}, inplace=True)

# %%
clean_divvy_trips = pd.concat([unclean_divvy_trips_a, unclean_divvy_trips_b])

# %%
clean_divvy_trips.reset_index(drop=True, inplace=True)
clean_divvy_trips
# Out:
#                 id                    date  station_id  \
# 0          8546790  12/31/2015 05:35:00 PM         117
# 1          8546793  12/31/2015 05:37:00 PM         301
# 2          8546795  12/31/2015 05:37:00 PM         465
# 3          8546797  12/31/2015 05:38:00 PM         333
# 4          8546798  12/31/2015 05:38:00 PM          48
# ...            ...                     ...         ...
# 42485475  25220103  09/30/2019 06:24:15 PM         332
# 42485476  25221957  09/30/2019 07:46:32 PM          38
# 42485477  25223072  09/30/2019 09:35:55 PM         347
# 42485478  25219153  09/30/2019 05:58:35 PM         289
# 42485479  25221024  09/30/2019 06:57:23 PM         332
#
#                                          station_name
# 0                            Wilton Ave & Belmont Ave
# 1                              Clark St & Schiller St
# 2                              Marine Dr & Ainslie St
# 3                          Ashland Ave & Blackhawk St
# ...

# %%
clean_divvy_trips['date'] = [datetime.datetime.strptime(clean_divvy_trips.date.loc[i], '%m/%d/%Y %I:%M:%S %p') for i in range(len(clean_divvy_trips))]
clean_divvy_trips
# Out:
#                 id                date  station_id  \
# 0          8546790 2015-12-31 17:35:00         117
# 1          8546793 2015-12-31 17:37:00         301
# 2          8546795 2015-12-31 17:37:00         465
# 3          8546797 2015-12-31 17:38:00         333
# 4          8546798 2015-12-31 17:38:00          48
# ...            ...                 ...         ...
# 42485475  25220103 2019-09-30 18:24:15         332
# 42485476  25221957 2019-09-30 19:46:32          38
# 42485477  25223072 2019-09-30 21:35:55         347
# 42485478  25219153 2019-09-30 17:58:35         289
# 42485479  25221024 2019-09-30 18:57:23         332
#
#                                          station_name
# 0                            Wilton Ave & Belmont Ave
# 1                              Clark St & Schiller St
# 2                              Marine Dr & Ainslie St
# 3                          Ashland Ave & Blackhawk St
# 4                          Larrabee St & Kingsbury St
# ...

# %%
clean_divvy_trips.sort_values(by='date', inplace=True)
clean_divvy_trips
# Out:
#                 id                date  station_id  \
# 2407464       3940 2013-06-27 01:06:00          91
# 23650204      3940 2013-06-27 01:06:00          48
# 2549912       4113 2013-06-27 11:09:00          88
# 23792652      4113 2013-06-27 11:09:00          88
# 2554972       4119 2013-06-27 11:12:00          88
# ...            ...                 ...         ...
# 37306045  25962902 2019-12-31 23:57:05          52
# 37298896  25962903 2019-12-31 23:57:11          52
# 16056156  25962903 2019-12-31 23:57:11         623
# 37294856  25962904 2019-12-31 23:57:17         240
# 16052116  25962904 2019-12-31 23:57:17         256
#
#                           station_name
# 2407464   Clinton St & Washington Blvd
# 23650204    Larrabee St & Kingsbury St
# 2549912           May St & Randolph St
# 23792652          May St & Randolph St
# 2554972           May St & Randolph St
# ...                                ...
# 37306045        Michigan Ave & Lake St
# ...

# %%
clean_divvy_trips.reset_index(drop=True, inplace=True)
clean_divvy_trips
# Out:
#                 id                date  station_id  \
# 0             3940 2013-06-27 01:06:00          91
# 1             3940 2013-06-27 01:06:00          48
# 2             4113 2013-06-27 11:09:00          88
# 3             4113 2013-06-27 11:09:00          88
# 4             4119 2013-06-27 11:12:00          88
# ...            ...                 ...         ...
# 42485475  25962902 2019-12-31 23:57:05          52
# 42485476  25962903 2019-12-31 23:57:11          52
# 42485477  25962903 2019-12-31 23:57:11         623
# 42485478  25962904 2019-12-31 23:57:17         240
# 42485479  25962904 2019-12-31 23:57:17         256
#
#                           station_name
# 0         Clinton St & Washington Blvd
# 1           Larrabee St & Kingsbury St
# 2                 May St & Randolph St
# 3                 May St & Randolph St
# 4                 May St & Randolph St
# ...                                ...
# 42485475        Michigan Ave & Lake St
# ...

# %%
clean_divvy_trips.to_csv('../clean_datasets/clean_divvy_trips.csv')

# %%
def convert_to_polygon(df):
    updated_polygons = []
    for row in df['the_geom']:
        target = row.replace('MULTIPOLYGON (((', '').replace(')))', '')
        points = target.split(', ')
        final = []
        for point in points:
            temp = point.split(' ')
            tup = float(temp[0]), float(temp[1]) 
            final.append(tup)
        updated_polygons.append(final)
    return updated_polygons

# %%
unclean_disadvantaged_areas = pd.read_csv('../original_datasets/unclean_disadvantaged_areas.csv')
unclean_disadvantaged_areas
# Out:
#                                               the_geom
# 0    MULTIPOLYGON (((-87.57366299996758 41.70796600...
# 1    MULTIPOLYGON (((-87.60151899995586 41.68632499...
# 2    MULTIPOLYGON (((-87.60036199996543 41.69284299...
# 3    MULTIPOLYGON (((-87.62032800000847 41.69942700...
# 4    MULTIPOLYGON (((-87.66036699995497 41.75771799...
# ..                                                 ...
# 275  MULTIPOLYGON (((-87.6624109999806 41.998169000...
# 276  MULTIPOLYGON (((-87.66572099996036 42.00497899...
# 277  MULTIPOLYGON (((-87.65500000001438 41.99831699...
# 278  MULTIPOLYGON (((-87.65029099995624 41.99662699...
# 279  MULTIPOLYGON (((-87.65438300000406 41.99020200...
#
# [280 rows x 1 columns]

# %%
clean_disadvantaged_areas = pd.DataFrame()
clean_disadvantaged_areas['poly'] = convert_to_polygon(unclean_disadvantaged_areas)
clean_disadvantaged_areas
# Out:
#                                                   poly
# 0    [(-87.57366299996758, 41.707966000031426), (-8...
# 1    [(-87.60151899995586, 41.68632499999862), (-87...
# 2    [(-87.60036199996543, 41.69284299996604), (-87...
# 3    [(-87.62032800000847, 41.69942700001048), (-87...
# 4    [(-87.66036699995497, 41.75771799998948), (-87...
# ..                                                 ...
# 275  [(-87.6624109999806, 41.998169000012545), (-87...
# 276  [(-87.66572099996036, 42.00497899998903), (-87...
# 277  [(-87.65500000001438, 41.998316999982876), (-8...
# 278  [(-87.65029099995624, 41.99662699998114), (-87...
# 279  [(-87.65438300000406, 41.99020200000654), (-87...
#
# [280 rows x 1 columns]

# %%
clean_disadvantaged_areas.to_csv('../clean_datasets/clean_disadvantaged_areas.csv')
